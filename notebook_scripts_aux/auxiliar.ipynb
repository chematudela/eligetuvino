# %% [markdown]
# ## NOTEBOOK PARA REALIZAR ALGUNAS TAREAS AUXILIARES CON LOS ARCHIVOS

# %%
import streamlit as st

# %%
import sys
print(sys.executable)
# Out:
# /Users/josetudela/Projects/EligeTuVino/eligetuvino/.venv/bin/python

# %%
# mover archivos a carpeta

import os
import shutil

# Carpeta de destino
dest_folder = "/Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100"

# Crear la carpeta si no existe
os.makedirs(dest_folder, exist_ok=True)


# Mover archivos
for i in range(1,11):  
    filename = f"/Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100_{i}.csv"
    if os.path.exists(filename):  # Verifica que el archivo exista
        shutil.move(filename, os.path.join(dest_folder, os.path.basename(filename)))
        print(f"Movido: {filename} → {dest_folder}/")
    else:
        print(f"No encontrado: {filename}")

print("✅ Proceso completado.")
# Out:
# No encontrado: /Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100_1.csv
# No encontrado: /Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100_2.csv
# No encontrado: /Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100_3.csv
# No encontrado: /Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100_4.csv
# No encontrado: /Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100_5.csv
# No encontrado: /Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100_6.csv
# No encontrado: /Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100_7.csv
# No encontrado: /Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100_8.csv
# No encontrado: /Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100_9.csv
# No encontrado: /Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100_10.csv
# ✅ Proceso completado.

# %%
#script para unir archivos

import os

# Ruta de la carpeta que contiene los archivos .txt
folder_path = '/Users/josetudela/Projects/vinos_grupo2/Proyecto_grupo2_vinos/src/Vinos blancos de 70 a 100'

# Nombre del archivo de salida
output_file = 'csv_Vinos blancos de 70 a 100.csv'

# Crear o abrir el archivo de salida en modo escritura
with open(output_file, 'w', encoding='utf-8') as outfile:
    # Iterar sobre todos los archivos de la carpeta
    for filename in os.listdir(folder_path):
        # Verificar si el archivo tiene extensión .txt
        if filename.endswith('.csv'):
            # Ruta completa del archivo
            file_path = os.path.join(folder_path, filename)
            
            # Abrir el archivo .txt en modo lectura
            with open(file_path, 'r', encoding='utf-8') as infile:
                # Escribir el contenido del archivo en el archivo de salida
                outfile.write(f"--- {filename} ---\n")  # Opcional: poner el nombre del archivo como título
                outfile.write(infile.read())  # Escribir el contenido del archivo
                outfile.write("\n\n")  # Agregar una línea vacía entre los archivos

# %%
country_mapping = {
        "Italia": "Italy",
        "Austria": "Austria",
        "España": "Spain",
        "Francia": "France",
        "Alemania": "Germany",
        "Sudáfrica": "South Africa",
        "Eslovenia": "Slovenia",
        "Australia": "Australia",
        "Portugal": "Portugal",
        "Argentina": "Argentina",
        "Hungría": "Hungary",
        "Grecia": "Greece",
        "New Zealand": "New Zealand",
        "Estados Unidos": "United States",
        "Chile": "Chile",
        "Croacia": "Croatia",
        "Rumanía": "Romania",
        "Bulgaria": "Bulgaria",
        "Marruecos": "Morocco",
        "Perú": "Peru",
        "Brasil": "Brazil",
        "Líbano": "Lebanon",
        "Luxembourg": "Luxembourg",
        "Suiza": "Switzerland",
        "Japón": "Japan",
        "Georgia": "Georgia",
        "Armenia": "Armenia",
        "Ucrania": "Ukraine",
        "México": "Mexico",
        "Reino Unido": "United Kingdom",
        "Israel": "Israel",
        "República Checa": "Czech Republic",
        "Países Bajos": "Netherlands",
        "Bélgica": "Belgium",
        "Canadá": "Canada",
        "Chipre": "Cyprus",
        "Norte de Macedonia": "North Macedonia",
        "Polonia": "Poland",
        "Serbia": "Serbia",
        "Eslovaquia": "Slovakia",
        "Uruguay": "Uruguay",
        "China": "China",
        "Moldavia": "Moldova",
        "Dinamarca": "Denmark",
        "Albania": "Albania",
        "Afganistán": "Afghanistan",
        "Albania": "Albania",
        "Algeria": "Algeria",
        "Andorra": "Andorra",
        "Angola": "Angola",
        "Antigua y Barbuda": "Antigua and Barbuda",
        "Arabia Saudita": "Saudi Arabia",
        "Argentina": "Argentina",
        "Armenia": "Armenia",
        "Australia": "Australia",
        "Austria": "Austria",
        "Azerbaiyán": "Azerbaijan",
        "Bahamas": "Bahamas",
        "Baréin": "Bahrain",
        "Bangladés": "Bangladesh",
        "Barbados": "Barbados",
        "Bélgica": "Belgium",
        "Belice": "Belize",
        "Benín": "Benin",
        "Bhután": "Bhutan",
        "Bielorrusia": "Belarus",
        "Birmania": "Myanmar",
        "Botsuana": "Botswana",
        "Brasil": "Brazil",
        "Brunéi": "Brunei",
        "Bulgaria": "Bulgaria",
        "Burkina Faso": "Burkina Faso",
        "Burundi": "Burundi",
        "Bután": "Bhutan",
        "Cabo Verde": "Cape Verde",
        "Camboya": "Cambodia",
        "Camerún": "Cameroon",
        "Canadá": "Canada",
        "Catar": "Qatar",
        "Chad": "Chad",
        "Chile": "Chile",
        "China": "China",
        "Chipre": "Cyprus",
        "Colombia": "Colombia",
        "Comoras": "Comoros",
        "Congo": "Congo",
        "Corea del Norte": "North Korea",
        "Corea del Sur": "South Korea",
        "Costa Rica": "Costa Rica",
        "Croacia": "Croatia",
        "Cuba": "Cuba",
        "Curazao": "Curaçao",
        "Chipre": "Cyprus",
        "República Checa": "Czech Republic",
        "Côte d'Ivoire": "Ivory Coast",
        "Dinamarca": "Denmark",
        "Djibouti": "Djibouti",
        "Dominica": "Dominica",
        "República Dominicana": "Dominican Republic",
        "Ecuador": "Ecuador",
        "Egipto": "Egypt",
        "El Salvador": "El Salvador",
        "Emiratos Árabes Unidos": "United Arab Emirates",
        "Ecuador": "Ecuador",
        "Eslovaquia": "Slovakia",
        "Eslovenia": "Slovenia",
        "España": "Spain",
        "Estados Unidos": "United States",
        "Etiopía": "Ethiopia",
        "Fiyi": "Fiji",
        "Filipinas": "Philippines",
        "Finlandia": "Finland",
        "Francia": "France",
        "Gabon": "Gabon",
        "Gambia": "Gambia",
        "Georgia": "Georgia",
        "Ghana": "Ghana",
        "Granada": "Grenada",
        "Grecia": "Greece",
        "Guatemala": "Guatemala",
        "Guinea": "Guinea",
        "Guinea-Bisáu": "Guinea-Bissau",
        "Guyana": "Guyana",
        "Haití": "Haiti",
        "Honduras": "Honduras",
        "Hungría": "Hungary",
        "India": "India",
        "Indonesia": "Indonesia",
        "Irak": "Iraq",
        "Irlanda": "Ireland",
        "Isla de Man": "Isle of Man",
        "Islas Cook": "Cook Islands",
        "Islas Feroe": "Faroe Islands",
        "Islas Malvinas": "Falkland Islands",
        "Islandia": "Iceland",
        "Israel": "Israel",
        "Italia": "Italy",
        "Jamaica": "Jamaica",
        "Japón": "Japan",
        "Jordania": "Jordan",
        "Kazajistán": "Kazakhstan",
        "Kenia": "Kenya",
        "Kirguistán": "Kyrgyzstan",
        "Kiribati": "Kiribati",
        "Kuwait": "Kuwait",
        "Laos": "Laos",
        "Lesoto": "Lesotho",
        "Letonia": "Latvia",
        "Líbano": "Lebanon",
        "Liberia": "Liberia",
        "Libia": "Libya",
        "Liechtenstein": "Liechtenstein",
        "Lituania": "Lithuania",
        "Luxemburgo": "Luxembourg",
        "Madagascar": "Madagascar",
        "Malasia": "Malaysia",
        "Malaui": "Malawi",
        "Maldivas": "Maldives",
        "Malta": "Malta",
        "Marruecos": "Morocco",
        "Mauricio": "Mauritius",
        "Mauritania": "Mauritania",
        "México": "Mexico",
        "Micronesia": "Micronesia",
        "Mónaco": "Monaco",
        "Mongolia": "Mongolia",
        "Mozambique": "Mozambique",
        "Namibia": "Namibia",
        "Nauru": "Nauru",
        "Nepal": "Nepal",
        "Nicaragua": "Nicaragua",
        "Níger": "Niger",
        "Nigeria": "Nigeria",
        "Noruega": "Norway",
        "Nueva Zelanda": "New Zealand",
        "Omán": "Oman",
        "Países Bajos": "Netherlands",
        "Pakistán": "Pakistan",
        "Palau": "Palau",
        "Panamá": "Panama",
        "Papúa Nueva Guinea": "Papua New Guinea",
        "Paraguay": "Paraguay",
        "Perú": "Peru",
        "Polonia": "Poland",
        "Portugal": "Portugal",
        "Reino Unido": "United Kingdom",
        "República Checa": "Czech Republic",
        "Rumanía": "Romania",
        "Rusia": "Russia",
        "Ruanda": "Rwanda",
        "Sahara Occidental": "Western Sahara",
        "Samoa": "Samoa",
        "San Cristóbal y Nieves": "Saint Kitts and Nevis",
        "San Marino": "San Marino",
        "Santa Lucía": "Saint Lucia",
        "Senegal": "Senegal",
        "Serbia": "Serbia",
        "Seychelles": "Seychelles",
        "Sierra Leona": "Sierra Leone",
        "Singapur": "Singapore",
        "Siria": "Syria",
        "Somalia": "Somalia",
        "Sri Lanka": "Sri Lanka",
        "Suazilandia": "Eswatini",
        "Sudán": "Sudan",
        "Sudáfrica": "South Africa",
        "Suecia": "Sweden",
        "Suiza": "Switzerland",
        "Surinam": "Suriname",
        "Siria": "Syria",
        "Somalia": "Somalia",
        "Sri Lanka": "Sri Lanka",
        "Tailandia": "Thailand",
        "Tanzania": "Tanzania",
        "Togo": "Togo",
        "Trinidad y Tobago": "Trinidad and Tobago",
        "Túnez": "Tunisia",
        "Turkmenistán": "Turkmenistan",
        "Turquía": "Turkey",
        "Tuvalu": "Tuvalu",
        "Uganda": "Uganda",
        "Ucrania": "Ukraine",
        "Uruguay": "Uruguay",
        "Uzbekistán": "Uzbekistan",
        "Vanuatu": "Vanuatu",
        "Vaticano": "Vatican",
        "Venezuela": "Venezuela",
        "Vietnam": "Vietnam",
        "Yemen": "Yemen",
        "Zambia": "Zambia",
        "Zimbabue": "Zimbabwe"
    }

# %%
country_mapping
# Out:
# {'Italia': 'Italy',
#  'Austria': 'Austria',
#  'España': 'Spain',
#  'Francia': 'France',
#  'Alemania': 'Germany',
#  'Sudáfrica': 'South Africa',
#  'Eslovenia': 'Slovenia',
#  'Australia': 'Australia',
#  'Portugal': 'Portugal',
#  'Argentina': 'Argentina',
#  'Hungría': 'Hungary',
#  'Grecia': 'Greece',
#  'New Zealand': 'New Zealand',
#  'Estados Unidos': 'United States',
#  'Chile': 'Chile',
#  'Croacia': 'Croatia',
#  'Rumanía': 'Romania',
#  'Bulgaria': 'Bulgaria',
#  'Marruecos': 'Morocco',
#  'Perú': 'Peru',
#  'Brasil': 'Brazil',
#  'Líbano': 'Lebanon',
#  'Luxembourg': 'Luxembourg',
#  'Suiza': 'Switzerland',
#  'Japón': 'Japan',
#  'Georgia': 'Georgia',
#  'Armenia': 'Armenia',
#  'Ucrania': 'Ukraine',
#  'México': 'Mexico',
#  'Reino Unido': 'United Kingdom',
#  'Israel': 'Israel',
#  'República Checa': 'Czech Republic',
#  'Países Bajos': 'Netherlands',
#  'Bélgica': 'Belgium',
#  'Canadá': 'Canada',
#  'Chipre': 'Cyprus',
#  'Norte de Macedonia': 'North Macedonia',
#  'Polonia': 'Poland',
#  'Serbia': 'Serbia',
#  'Eslovaquia': 'Slovakia',
#  'Uruguay': 'Uruguay',
#  'China': 'China',
#  'Moldavia': 'Moldova',
#  'Dinamarca': 'Denmark',
#  'Albania': 'Albania',
#  'Afganistán': 'Afghanistan',
#  'Algeria': 'Algeria',
#  'Andorra': 'Andorra',
#  'Angola': 'Angola',
#  'Antigua y Barbuda': 'Antigua and Barbuda',
#  'Arabia Saudita': 'Saudi Arabia',
#  'Azerbaiyán': 'Azerbaijan',
#  'Bahamas': 'Bahamas',
#  'Baréin': 'Bahrain',
#  'Bangladés': 'Bangladesh',
#  'Barbados': 'Barbados',
#  'Belice': 'Belize',
#  'Benín': 'Benin',
#  'Bhután': 'Bhutan',
#  'Bielorrusia': 'Belarus',
#  'Birmania': 'Myanmar',
#  'Botsuana': 'Botswana',
#  'Brunéi': 'Brunei',
#  'Burkina Faso': 'Burkina Faso',
#  'Burundi': 'Burundi',
#  'Bután': 'Bhutan',
#  'Cabo Verde': 'Cape Verde',
#  'Camboya': 'Cambodia',
#  'Camerún': 'Cameroon',
#  'Catar': 'Qatar',
#  'Chad': 'Chad',
#  'Colombia': 'Colombia',
#  'Comoras': 'Comoros',
#  'Congo': 'Congo',
#  'Corea del Norte': 'North Korea',
#  'Corea del Sur': 'South Korea',
#  'Costa Rica': 'Costa Rica',
#  'Cuba': 'Cuba',
#  'Curazao': 'Curaçao',
#  "Côte d'Ivoire": 'Ivory Coast',
#  'Djibouti': 'Djibouti',
#  'Dominica': 'Dominica',
#  'República Dominicana': 'Dominican Republic',
#  'Ecuador': 'Ecuador',
#  'Egipto': 'Egypt',
#  'El Salvador': 'El Salvador',
#  'Emiratos Árabes Unidos': 'United Arab Emirates',
#  'Etiopía': 'Ethiopia',
#  'Fiyi': 'Fiji',
#  'Filipinas': 'Philippines',
#  'Finlandia': 'Finland',
#  'Gabon': 'Gabon',
#  'Gambia': 'Gambia',
#  'Ghana': 'Ghana',
#  'Granada': 'Grenada',
#  'Guatemala': 'Guatemala',
#  'Guinea': 'Guinea',
#  'Guinea-Bisáu': 'Guinea-Bissau',
#  'Guyana': 'Guyana',
#  'Haití': 'Haiti',
#  'Honduras': 'Honduras',
#  'India': 'India',
#  'Indonesia': 'Indonesia',
#  'Irak': 'Iraq',
#  'Irlanda': 'Ireland',
#  'Isla de Man': 'Isle of Man',
#  'Islas Cook': 'Cook Islands',
#  'Islas Feroe': 'Faroe Islands',
#  'Islas Malvinas': 'Falkland Islands',
#  'Islandia': 'Iceland',
#  'Jamaica': 'Jamaica',
#  'Jordania': 'Jordan',
#  'Kazajistán': 'Kazakhstan',
#  'Kenia': 'Kenya',
#  'Kirguistán': 'Kyrgyzstan',
#  'Kiribati': 'Kiribati',
#  'Kuwait': 'Kuwait',
#  'Laos': 'Laos',
#  'Lesoto': 'Lesotho',
#  'Letonia': 'Latvia',
#  'Liberia': 'Liberia',
#  'Libia': 'Libya',
#  'Liechtenstein': 'Liechtenstein',
#  'Lituania': 'Lithuania',
#  'Luxemburgo': 'Luxembourg',
#  'Madagascar': 'Madagascar',
#  'Malasia': 'Malaysia',
#  'Malaui': 'Malawi',
#  'Maldivas': 'Maldives',
#  'Malta': 'Malta',
#  'Mauricio': 'Mauritius',
#  'Mauritania': 'Mauritania',
#  'Micronesia': 'Micronesia',
#  'Mónaco': 'Monaco',
#  'Mongolia': 'Mongolia',
#  'Mozambique': 'Mozambique',
#  'Namibia': 'Namibia',
#  'Nauru': 'Nauru',
#  'Nepal': 'Nepal',
#  'Nicaragua': 'Nicaragua',
#  'Níger': 'Niger',
#  'Nigeria': 'Nigeria',
#  'Noruega': 'Norway',
#  'Nueva Zelanda': 'New Zealand',
#  'Omán': 'Oman',
#  'Pakistán': 'Pakistan',
#  'Palau': 'Palau',
#  'Panamá': 'Panama',
#  'Papúa Nueva Guinea': 'Papua New Guinea',
#  'Paraguay': 'Paraguay',
#  'Rusia': 'Russia',
#  'Ruanda': 'Rwanda',
#  'Sahara Occidental': 'Western Sahara',
#  'Samoa': 'Samoa',
#  'San Cristóbal y Nieves': 'Saint Kitts and Nevis',
#  'San Marino': 'San Marino',
#  'Santa Lucía': 'Saint Lucia',
#  'Senegal': 'Senegal',
#  'Seychelles': 'Seychelles',
#  'Sierra Leona': 'Sierra Leone',
#  'Singapur': 'Singapore',
#  'Siria': 'Syria',
#  'Somalia': 'Somalia',
#  'Sri Lanka': 'Sri Lanka',
#  'Suazilandia': 'Eswatini',
#  'Sudán': 'Sudan',
#  'Suecia': 'Sweden',
#  'Surinam': 'Suriname',
#  'Tailandia': 'Thailand',
#  'Tanzania': 'Tanzania',
#  'Togo': 'Togo',
#  'Trinidad y Tobago': 'Trinidad and Tobago',
#  'Túnez': 'Tunisia',
#  'Turkmenistán': 'Turkmenistan',
#  'Turquía': 'Turkey',
#  'Tuvalu': 'Tuvalu',
#  'Uganda': 'Uganda',
#  'Uzbekistán': 'Uzbekistan',
#  'Vanuatu': 'Vanuatu',
#  'Vaticano': 'Vatican',
#  'Venezuela': 'Venezuela',
#  'Vietnam': 'Vietnam',
#  'Yemen': 'Yemen',
#  'Zambia': 'Zambia',
#  'Zimbabue': 'Zimbabwe'}

# %%
import json

with open('country_mapping.json', 'w', encoding="utf-8") as f:
    json.dump(country_mapping, f,ensure_ascii=False)

# %%
with open('../data/datasets/processed/country_mapping.json', 'r', encoding="utf-8") as f:
    country_mapping = json.load(f)

# %%
country_mapping
# Out:
# {'Italia': 'Italy',
#  'Austria': 'Austria',
#  'España': 'Spain',
#  'Francia': 'France',
#  'Alemania': 'Germany',
#  'Sudáfrica': 'South Africa',
#  'Eslovenia': 'Slovenia',
#  'Australia': 'Australia',
#  'Portugal': 'Portugal',
#  'Argentina': 'Argentina',
#  'Hungría': 'Hungary',
#  'Grecia': 'Greece',
#  'New Zealand': 'New Zealand',
#  'Estados Unidos': 'United States',
#  'Chile': 'Chile',
#  'Croacia': 'Croatia',
#  'Rumanía': 'Romania',
#  'Bulgaria': 'Bulgaria',
#  'Marruecos': 'Morocco',
#  'Perú': 'Peru',
#  'Brasil': 'Brazil',
#  'Líbano': 'Lebanon',
#  'Luxembourg': 'Luxembourg',
#  'Suiza': 'Switzerland',
#  'Japón': 'Japan',
#  'Georgia': 'Georgia',
#  'Armenia': 'Armenia',
#  'Ucrania': 'Ukraine',
#  'México': 'Mexico',
#  'Reino Unido': 'United Kingdom',
#  'Israel': 'Israel',
#  'República Checa': 'Czech Republic',
#  'Países Bajos': 'Netherlands',
#  'Bélgica': 'Belgium',
#  'Canadá': 'Canada',
#  'Chipre': 'Cyprus',
#  'Norte de Macedonia': 'North Macedonia',
#  'Polonia': 'Poland',
#  'Serbia': 'Serbia',
#  'Eslovaquia': 'Slovakia',
#  'Uruguay': 'Uruguay',
#  'China': 'China',
#  'Moldavia': 'Moldova',
#  'Dinamarca': 'Denmark',
#  'Albania': 'Albania',
#  'Afganistán': 'Afghanistan',
#  'Algeria': 'Algeria',
#  'Andorra': 'Andorra',
#  'Angola': 'Angola',
#  'Antigua y Barbuda': 'Antigua and Barbuda',
#  'Arabia Saudita': 'Saudi Arabia',
#  'Azerbaiyán': 'Azerbaijan',
#  'Bahamas': 'Bahamas',
#  'Baréin': 'Bahrain',
#  'Bangladés': 'Bangladesh',
#  'Barbados': 'Barbados',
#  'Belice': 'Belize',
#  'Benín': 'Benin',
#  'Bhután': 'Bhutan',
#  'Bielorrusia': 'Belarus',
#  'Birmania': 'Myanmar',
#  'Botsuana': 'Botswana',
#  'Brunéi': 'Brunei',
#  'Burkina Faso': 'Burkina Faso',
#  'Burundi': 'Burundi',
#  'Bután': 'Bhutan',
#  'Cabo Verde': 'Cape Verde',
#  'Camboya': 'Cambodia',
#  'Camerún': 'Cameroon',
#  'Catar': 'Qatar',
#  'Chad': 'Chad',
#  'Colombia': 'Colombia',
#  'Comoras': 'Comoros',
#  'Congo': 'Congo',
#  'Corea del Norte': 'North Korea',
#  'Corea del Sur': 'South Korea',
#  'Costa Rica': 'Costa Rica',
#  'Cuba': 'Cuba',
#  'Curazao': 'Curaçao',
#  "Côte d'Ivoire": 'Ivory Coast',
#  'Djibouti': 'Djibouti',
#  'Dominica': 'Dominica',
#  'República Dominicana': 'Dominican Republic',
#  'Ecuador': 'Ecuador',
#  'Egipto': 'Egypt',
#  'El Salvador': 'El Salvador',
#  'Emiratos Árabes Unidos': 'United Arab Emirates',
#  'Etiopía': 'Ethiopia',
#  'Fiyi': 'Fiji',
#  'Filipinas': 'Philippines',
#  'Finlandia': 'Finland',
#  'Gabon': 'Gabon',
#  'Gambia': 'Gambia',
#  'Ghana': 'Ghana',
#  'Granada': 'Grenada',
#  'Guatemala': 'Guatemala',
#  'Guinea': 'Guinea',
#  'Guinea-Bisáu': 'Guinea-Bissau',
#  'Guyana': 'Guyana',
#  'Haití': 'Haiti',
#  'Honduras': 'Honduras',
#  'India': 'India',
#  'Indonesia': 'Indonesia',
#  'Irak': 'Iraq',
#  'Irlanda': 'Ireland',
#  'Isla de Man': 'Isle of Man',
#  'Islas Cook': 'Cook Islands',
#  'Islas Feroe': 'Faroe Islands',
#  'Islas Malvinas': 'Falkland Islands',
#  'Islandia': 'Iceland',
#  'Jamaica': 'Jamaica',
#  'Jordania': 'Jordan',
#  'Kazajistán': 'Kazakhstan',
#  'Kenia': 'Kenya',
#  'Kirguistán': 'Kyrgyzstan',
#  'Kiribati': 'Kiribati',
#  'Kuwait': 'Kuwait',
#  'Laos': 'Laos',
#  'Lesoto': 'Lesotho',
#  'Letonia': 'Latvia',
#  'Liberia': 'Liberia',
#  'Libia': 'Libya',
#  'Liechtenstein': 'Liechtenstein',
#  'Lituania': 'Lithuania',
#  'Luxemburgo': 'Luxembourg',
#  'Madagascar': 'Madagascar',
#  'Malasia': 'Malaysia',
#  'Malaui': 'Malawi',
#  'Maldivas': 'Maldives',
#  'Malta': 'Malta',
#  'Mauricio': 'Mauritius',
#  'Mauritania': 'Mauritania',
#  'Micronesia': 'Micronesia',
#  'Mónaco': 'Monaco',
#  'Mongolia': 'Mongolia',
#  'Mozambique': 'Mozambique',
#  'Namibia': 'Namibia',
#  'Nauru': 'Nauru',
#  'Nepal': 'Nepal',
#  'Nicaragua': 'Nicaragua',
#  'Níger': 'Niger',
#  'Nigeria': 'Nigeria',
#  'Noruega': 'Norway',
#  'Nueva Zelanda': 'New Zealand',
#  'Omán': 'Oman',
#  'Pakistán': 'Pakistan',
#  'Palau': 'Palau',
#  'Panamá': 'Panama',
#  'Papúa Nueva Guinea': 'Papua New Guinea',
#  'Paraguay': 'Paraguay',
#  'Rusia': 'Russia',
#  'Ruanda': 'Rwanda',
#  'Sahara Occidental': 'Western Sahara',
#  'Samoa': 'Samoa',
#  'San Cristóbal y Nieves': 'Saint Kitts and Nevis',
#  'San Marino': 'San Marino',
#  'Santa Lucía': 'Saint Lucia',
#  'Senegal': 'Senegal',
#  'Seychelles': 'Seychelles',
#  'Sierra Leona': 'Sierra Leone',
#  'Singapur': 'Singapore',
#  'Siria': 'Syria',
#  'Somalia': 'Somalia',
#  'Sri Lanka': 'Sri Lanka',
#  'Suazilandia': 'Eswatini',
#  'Sudán': 'Sudan',
#  'Suecia': 'Sweden',
#  'Surinam': 'Suriname',
#  'Tailandia': 'Thailand',
#  'Tanzania': 'Tanzania',
#  'Togo': 'Togo',
#  'Trinidad y Tobago': 'Trinidad and Tobago',
#  'Túnez': 'Tunisia',
#  'Turkmenistán': 'Turkmenistan',
#  'Turquía': 'Turkey',
#  'Tuvalu': 'Tuvalu',
#  'Uganda': 'Uganda',
#  'Uzbekistán': 'Uzbekistan',
#  'Vanuatu': 'Vanuatu',
#  'Vaticano': 'Vatican',
#  'Venezuela': 'Venezuela',
#  'Vietnam': 'Vietnam',
#  'Yemen': 'Yemen',
#  'Zambia': 'Zambia',
#  'Zimbabue': 'Zimbabwe'}

# %%
import pandas as pd
df = pd.read_csv("../data/datasets/raw/FINAL_DF_TINTOS_PRECIO_CORREGIDO.csv")

# %%
import streamlit as st
import pandas as pd
import joblib
import requests
from bs4 import BeautifulSoup
from sklearn.preprocessing import MinMaxScaler

# %%
# Carga de datos

X_train = pd.read_csv("data/datasets/processed/X_train_imputed.csv")
y_train = pd.read_csv("data/datasets/processed/y_train.csv")
X_test = pd.read_csv("data/datasets/processed/X_test_imputed.csv")
y_test = pd.read_csv("data/datasets/processed/y_test.csv")

df_final_tintos_corregido = pd.read_csv("data/datasets/raw/FINAL_DF_TINTOS_PRECIO_CORREGIDO.csv")

# Cepillado de datos 

X_train["Valoración"] = y_train["Valoración"]
X_test["Valoración"] = y_test["Valoración"]
df_total =  pd.concat([X_train, X_test], ignore_index=True)
df_total["ID"] = df_total["ID"].astype(int)
df_total["Precio"] = df_total["Precio"].astype(float)
df_total_cluster = df_total.drop(columns=["Unnamed: 0","ID","Precio"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Carga de datos
# ----> 3 X_train = pd.read_csv("data/datasets/processed/X_train_imputed.csv")
#       4 y_train = pd.read_csv("data/datasets/processed/y_train.csv")
#       5 X_test = pd.read_csv("data/datasets/processed/X_test_imputed.csv")
#
# NameError: name 'pd' is not defined

# %%
id = df.loc[df["Url"] == "https://www.vivino.com/ES/es/costaripa-maim/w/23370", "ID"].values[0]
id = int(id)
id
# Out:
# 23370

# %%
df_final_tintos_corregido = pd.read_csv("../data/datasets/raw/FINAL_DF_TINTOS_PRECIO_CORREGIDO.csv")

# %%
df_final_tintos_corregido
# Out:
#        Unnamed: 0                                                Url  \
# 0               0  https://www.vivino.com/ES/es/crealto-pionda/w/...
# 1               1  https://www.vivino.com/ES/es/karpatska-perla-v...
# 2               2  https://www.vivino.com/ES/es/giachino-giac-pot...
# 3               3  https://www.vivino.com/ES/es/pelz-pinot-nero/w...
# 4               4  https://www.vivino.com/ES/es/finca-la-capilla-...
# ...           ...                                                ...
# 20153       20153  https://www.vivino.com/ES/es/cantina-di-santad...
# 20154       20154  https://www.vivino.com/ES/es/es-nueva-crianza/...
# 20155       20155  https://www.vivino.com/ES/es/campestral-especi...
# 20156       20156  https://www.vivino.com/ES/es/portal-del-monsta...
# 20157       20157  https://www.vivino.com/ES/es/es-prohom-experie...
#
#              ID                              Nombre            Año  \
# 0       3105259                              Pionda           2018
# 1       1280319             Varieto Frankovka Modrá           2021
# 2       6365197                         Giac' Potes           2023
# 3       2573275                          Pinot Nero           2020
# 4       1133110    La Capilla Vendimia Seleccionada           2021
# ...         ...                                 ...            ...
# 20153     17967   Grotta Rossa Carignano del Sulcis           2022
# 20154   1210509                             Crianza           2018
# 20155  11571930                      Especial Tinto           2020
# 20156   1437498  Santes Negre Sustainable Vineyards  No disponible
# 20157   5731154            Prohom Experientia Negre           2021
#
#              País                  Región               Bodega Tipo de vino  \
# 0          Italia              Monferrato              Crealto   Vino tinto
# 1      Eslovaquia           Malokarpatská      Karpatská Perla   Vino tinto
# 2         Francia                  Savoie     Domaine Giachino   Vino tinto
# 3          Italia  Vigneti delle Dolomiti                 Pelz   Vino tinto
# 4          España        Ribera del Duero     Finca La Capilla   Vino tinto
# ...           ...                     ...                  ...          ...
# 20153      Italia    Carignano del Sulcis              Santadi   Vino tinto
# 20154      España                   Rioja          Finca Nueva   Vino tinto
# 20155      España          Vino de España           Campestral   Vino tinto
# 20156      España                Montsant  Portal del Montsant   Vino tinto
# 20157      España              Terra Alta      Coma d'En Bonet   Vino tinto
#
#                                                      Uva  ...  Valoración  \
# 0                                               Nebbiolo  ...         3.8
# 1                                          Blaufränkisch  ...         3.5
# 2                                  Gamay, Mondeuse Noire  ...         3.8
# 3                                             Pinot Nero  ...         3.8
# 4                                         Tinta del Pais  ...         4.3
# ...                                                  ...  ...         ...
# 20153                                           Carignan  ...         3.6
# 20154                                        Tempranillo  ...         3.7
# 20155  Tintilla de Rota, Shiraz/Syrah, Cabernet Sauvi...  ...         3.7
# 20156                                      Ull de Llebre  ...         3.5
# 20157  Shiraz/Syrah, Cabernet Sauvignon, Cariñena, Ga...  ...         3.9
#
#       Contenido de alcohol                                          Maridajes  \
# 0                        5              Ternera, Cordero, Aves, Carne de caza
# 1                       13              Ternera, Cordero, Aves, Carne de caza
# 2            No disponible  Ternera, Carne de caza, Queso curado, Queso ti...
# 3            No disponible       Ternera, Ternera lechal, Aves, Carne de caza
# 4                       15                    Ternera, Cordero, Carne de caza
# ...                    ...                                                ...
# 20153                   14                            Ternera, Cordero, Pasta
# 20154                   13             Ternera, Cordero, Ternera lechal, Aves
# 20155                   13               Ternera, Ternera lechal, Aves, Pasta
# 20156                    5                            Ternera, Cordero, Pasta
# 20157                   14               Ternera, Ternera lechal, Aves, Pasta
#
#       Ligero/Poderoso Suave/Tánico Seco/Dulce Débil/Ácido  \
# 0                 5.5          7.6        0.1         8.0
# 1                 4.9          5.3        2.5         5.8
# 2                 3.0          3.4        0.0         6.5
# 3                 4.0          3.5        1.9         4.5
# 4                 6.6          5.4        1.3         4.9
# ...               ...          ...        ...         ...
# 20153             7.3          4.0        2.6         3.3
# 20154             6.1          6.1        0.7         6.1
# 20155             4.9          4.7        2.8         4.7
# 20156             6.9          4.3        1.3         4.9
# 20157             6.4          4.2        1.8         4.8
#
#                      Taste_Note_1                Taste_Note_2  \
# 0      Terroso, cuero, virutas...  fresa, cereza, arándano...
# 1            cereza, frutos rojos             Terroso, piedra
# 2      fresa, frambuesa, cerez...  casis, mora, fruta negr...
# 3                   No disponible               No disponible
# 4      ciruela, fruta negra, c...     roble, vainilla, tabaco
# ...                           ...                         ...
# 20153        Terroso, cuero, humo  cereza, frutos rojos, f...
# 20154     roble, vainilla, tabaco  cereza, frutos rojos, c...
# 20155               No disponible               No disponible
# 20156  fruta negra, mora, arán...  cereza, frambuesa, fres...
# 20157  casis, ciruela, cereza ...  chocolate, tabaco, vain...
#
#                      Taste_Note_3
# 0      frutos del bosque, merm...
# 1      chocolate, tabaco, vain...
# 2      Terroso, minerales, cue...
# 3                   No disponible
# 4          cuero, Terroso, ceniza
# ...                           ...
# 20153  roble, chocolate, tabac...
# 20154  mora, cereza negra, cir...
# 20155               No disponible
# 20156  Terroso, carne a la par...
# 20157                     regaliz
#
# [20158 rows x 21 columns]

# %%
df_total["País_encoded"][0]
# Out:
# np.float64(3.993496038591642)

# %%
from sklearn.preprocessing import MinMaxScaler
import joblib
X_train = pd.read_csv("../data/datasets/processed/X_train_imputed.csv")
y_train = pd.read_csv("../data/datasets/processed/y_train.csv")
X_test = pd.read_csv("../data/datasets/processed/X_test_imputed.csv")
y_test = pd.read_csv("../data/datasets/processed/y_test.csv")

df_final_tintos_corregido = pd.read_csv("../data/datasets/raw/FINAL_DF_TINTOS_PRECIO_CORREGIDO.csv")

# Cepillado de datos 


X_train["Valoración"] = y_train["Valoración"]
X_test["Valoración"] = y_test["Valoración"]
df_total =  pd.concat([X_train, X_test], ignore_index=True)
df_total["ID"] = df_total["ID"].astype(int)
df_total["Precio"] = df_total["Precio"].astype(float)
df_total_cluster = df_total.drop(columns=["Unnamed: 0","ID","Precio"])
X_train_dict_pais = pd.read_csv("../data/datasets/processed/X_train_dict_pais.csv")


    # Escalado de datos
scaler = MinMaxScaler()  # Crear el escalador
df_total_scaled = pd.DataFrame(scaler.fit_transform(df_total_cluster), columns=df_total_cluster.columns)

# Importamos el modelo kmeans
model_KM = joblib.load("../src/modelos/kmeans_model.pkl")
predictions = model_KM.predict(df_total_scaled)

# Añadimos la columna cluster al dataset
df_total["cluster"] = predictions

# %%
id = df_final_tintos_corregido.loc[df_final_tintos_corregido["Url"] == "https://www.vivino.com/ES/es/valdaya-tinto/w/1167755", "ID"].values[0]
id = int(id)
id
# Out:
# 1167755

# %%
def dic_pais(nombre_pais):
    X_train_dict_pais = pd.read_csv("../data/datasets/processed/X_train_dict_pais.csv")
    dic = dict(zip(X_train_dict_pais["País"], X_train_dict_pais["País_encoded"]))

    def obtener_clave(diccionario, valor_buscado):
        for clave, valor in diccionario.items():
            if valor == valor_buscado:
                return clave
    
    return obtener_clave(dic, nombre_pais)

# %%
def dic_pais2(nombre_pais):
    X_train_dict_pais = pd.read_csv("../data/datasets/processed/X_train_dict_pais.csv")
    dic = dict(zip(X_train_dict_pais["País"], X_train_dict_pais["País_encoded"]))
    return dic[nombre_pais]

# %%
dic_pais2("España")
# Out:
# 3.860382783665711

# %%
pais_ = dic_pais(3.860382783665711)

# %%
print(pais_)
# Out:
# España

# %%
pais = "España"

# %%
cluster = df_total[df_total["ID"] == id]["cluster"].iloc[0]
cluster
# Out:
# np.int32(18)

# %%
pru = df_total[df_total["País_encoded"] == dic_pais2(pais)]["Precio"].idxmin()

# %%
indice_min_precio = df_total[(df_total["cluster"] == cluster)&(df_total["País_encoded"] == dic_pais2(pais))]["Precio"].idxmin()

# %%
indice_min_precio
# Out:
# np.int64(14938)

# %%
pru
# Out:
# np.int64(15153)

# %%
indice_min_precio = df_total[(df_total["cluster"] == cluster)]["Precio"].idxmin()

# %%
indice_min_precio
# Out:
# np.int64(7205)

# %%
X_train_dict_pais = pd.read_csv("../data/datasets/processed/X_train_dict_pais.csv")

# %%
def dic_pais(nombre_pais):
    
    
    dic = dict(zip(X_train_dict_pais["País_enconded"], X_train_dict_pais["País"]))
    return  dic[nombre_pais]
